# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/content/train.csv")

# %%
df=df.drop(columns=["nums_length_of_username"])

# %%
df.head()
# Out:
#    profile_pic  fullname_words  nums_length_fullname  name_username  \
# 0            1               0                   0.0              0
# 1            1               2                   0.0              0
# 2            1               2                   0.0              0
# 3            1               1                   0.0              0
# 4            1               2                   0.0              0
#
#    description_length  external_URL  private  no_of_posts  no_of_followers  \
# 0                  53             0        0           32             1000
# 1                  44             0        0          286             2740
# 2                   0             0        1           13              159
# 3                  82             0        0          679              414
# 4                   0             0        1            6              151
#
#    no_of_following  fake
# 0              955     0
# 1              533     0
# 2               98     0
# 3              651     0
# 4              126     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   profile_pic           576 non-null    int64
#  1   fullname_words        576 non-null    int64
#  2   nums_length_fullname  576 non-null    float64
#  3   name_username         576 non-null    int64
#  4   description_length    576 non-null    int64
#  5   external_URL          576 non-null    int64
#  6   private               576 non-null    int64
#  7   no_of_posts           576 non-null    int64
#  8   no_of_followers       576 non-null    int64
#  9   no_of_following       576 non-null    int64
#  10  fake                  576 non-null    int64
# dtypes: float64(1), int64(10)
# memory usage: 49.6 KB

# %%
df.corr()
# Out:
#                       profile_pic  fullname_words  nums_length_fullname  \
# profile_pic              1.000000        0.213295             -0.131756
# fullname_words           0.213295        1.000000             -0.094348
# nums_length_fullname    -0.131756       -0.094348              1.000000
# name_username           -0.124903       -0.082969              0.291149
# description_length       0.367892        0.272522             -0.117521
# external_URL             0.236729        0.196562             -0.088724
# private                  0.114732       -0.089070             -0.030030
# no_of_posts              0.169570        0.073350             -0.057716
# no_of_followers          0.061137        0.033225             -0.027035
# no_of_following          0.194833        0.094855             -0.067971
# fake                    -0.637315       -0.298793              0.246782
#
#                       name_username  description_length  external_URL  \
# profile_pic               -0.124903            0.367892      0.236729
# fullname_words            -0.082969            0.272522      0.196562
# nums_length_fullname       0.291149           -0.117521     -0.088724
# name_username              1.000000           -0.064814     -0.039232
# description_length        -0.064814            1.000000      0.482313
# external_URL              -0.039232            0.482313      1.000000
# private                    0.046084           -0.110329     -0.162612
# no_of_posts               -0.049808            0.144824      0.165008
# no_of_followers           -0.017761            0.005929      0.027189
# no_of_following           -0.009529            0.226561      0.142519
# fake                       0.170695           -0.460825     -0.362809
#
#                        private  no_of_posts  no_of_followers  no_of_following  \
# profile_pic           0.114732     0.169570         0.061137         0.194833
# fullname_words       -0.089070     0.073350         0.033225         0.094855
# nums_length_fullname -0.030030    -0.057716        -0.027035        -0.067971
# name_username         0.046084    -0.049808        -0.017761        -0.009529
# description_length   -0.110329     0.144824         0.005929         0.226561
# external_URL         -0.162612     0.165008         0.027189         0.142519
# private               1.000000    -0.087495        -0.073473        -0.057542
# no_of_posts          -0.087495     1.000000         0.321385         0.098225
# no_of_followers      -0.073473     0.321385         1.000000        -0.011066
# no_of_following      -0.057542     0.098225        -0.011066         1.000000
# fake                 -0.028586    -0.245355        -0.093689        -0.224835
#
#                           fake
# profile_pic          -0.637315
# fullname_words       -0.298793
# nums_length_fullname  0.246782
# name_username         0.170695
# description_length   -0.460825
# external_URL         -0.362809
# private              -0.028586
# no_of_posts          -0.245355
# no_of_followers      -0.093689
# no_of_following      -0.224835
# fake                  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='Reds')
# Out:
# <Axes: >

# %%
fake_high_chance=df[df["fake"]>=0.8]
fake_high_chance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288 entries, 288 to 575
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   profile_pic           288 non-null    int64
#  1   fullname_words        288 non-null    int64
#  2   nums_length_fullname  288 non-null    float64
#  3   name_username         288 non-null    int64
#  4   description_length    288 non-null    int64
#  5   external_URL          288 non-null    int64
#  6   private               288 non-null    int64
#  7   no_of_posts           288 non-null    int64
#  8   no_of_followers       288 non-null    int64
#  9   no_of_following       288 non-null    int64
#  10  fake                  288 non-null    int64
# dtypes: float64(1), int64(10)
# memory usage: 27.0 KB

# %%
fake_high_chance.corr()
# Out:
#                       profile_pic  fullname_words  nums_length_fullname  \
# profile_pic              1.000000        0.039562              0.034925
# fullname_words           0.039562        1.000000             -0.038557
# nums_length_fullname     0.034925       -0.038557              1.000000
# name_username           -0.022320       -0.057276              0.273916
# description_length       0.243207        0.080014             -0.045951
# external_URL                  NaN             NaN                   NaN
# private                  0.198655       -0.207029             -0.028991
# no_of_posts              0.286045        0.107682              0.030746
# no_of_followers          0.042088        0.042850             -0.062720
# no_of_following          0.124544        0.037859             -0.035898
# fake                          NaN             NaN                   NaN
#
#                       name_username  description_length  external_URL  \
# profile_pic               -0.022320            0.243207           NaN
# fullname_words            -0.057276            0.080014           NaN
# nums_length_fullname       0.273916           -0.045951           NaN
# name_username              1.000000            0.010347           NaN
# description_length         0.010347            1.000000           NaN
# external_URL                    NaN                 NaN           NaN
# private                    0.058208            0.033770           NaN
# no_of_posts               -0.072412            0.080788           NaN
# no_of_followers            0.036651            0.121675           NaN
# no_of_following            0.067527            0.051611           NaN
# fake                            NaN                 NaN           NaN
#
#                        private  no_of_posts  no_of_followers  no_of_following  \
# profile_pic           0.198655     0.286045         0.042088         0.124544
# fullname_words       -0.207029     0.107682         0.042850         0.037859
# nums_length_fullname -0.028991     0.030746        -0.062720        -0.035898
# name_username         0.058208    -0.072412         0.036651         0.067527
# description_length    0.033770     0.080788         0.121675         0.051611
# external_URL               NaN          NaN              NaN              NaN
# private               1.000000     0.123337        -0.094753        -0.056738
# no_of_posts           0.123337     1.000000         0.072308         0.188808
# no_of_followers      -0.094753     0.072308         1.000000         0.605396
# no_of_following      -0.056738     0.188808         0.605396         1.000000
# fake                       NaN          NaN              NaN              NaN
#
#                       fake
# profile_pic            NaN
# fullname_words         NaN
# nums_length_fullname   NaN
# name_username          NaN
# description_length     NaN
# external_URL           NaN
# private                NaN
# no_of_posts            NaN
# no_of_followers        NaN
# no_of_following        NaN
# fake                   NaN

# %%
df.describe()
# Out:
#        profile_pic  fullname_words  nums_length_fullname  name_username  \
# count   576.000000      576.000000            576.000000     576.000000
# mean      0.701389        1.460069              0.036094       0.034722
# std       0.458047        1.052601              0.125121       0.183234
# min       0.000000        0.000000              0.000000       0.000000
# 25%       0.000000        1.000000              0.000000       0.000000
# 50%       1.000000        1.000000              0.000000       0.000000
# 75%       1.000000        2.000000              0.000000       0.000000
# max       1.000000       12.000000              1.000000       1.000000
#
#        description_length  external_URL     private  no_of_posts  \
# count          576.000000    576.000000  576.000000   576.000000
# mean            22.623264      0.116319    0.381944   107.489583
# std             37.702987      0.320886    0.486285   402.034431
# min              0.000000      0.000000    0.000000     0.000000
# 25%              0.000000      0.000000    0.000000     0.000000
# 50%              0.000000      0.000000    0.000000     9.000000
# 75%             34.000000      0.000000    1.000000    81.500000
# max            150.000000      1.000000    1.000000  7389.000000
#
#        no_of_followers  no_of_following        fake
# count     5.760000e+02       576.000000  576.000000
# mean      8.530724e+04       508.381944    0.500000
# std       9.101485e+05       917.981239    0.500435
# min       0.000000e+00         0.000000    0.000000
# 25%       3.900000e+01        57.500000    0.000000
# 50%       1.505000e+02       229.500000    0.500000
# 75%       7.160000e+02       589.500000    1.000000
# max       1.533854e+07      7500.000000    1.000000

# %%
X=df["nums_length_fullname"].values
X=X/0.04
y=df["fake"].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
lr =LinearRegression()

# %%
lr.fit(X_train.reshape(-1,1), y_train)
y_pred=lr.predict(X_test.reshape(-1,1))

# %%
lr.score (X_test.reshape(-1,1),y_test.reshape(-1,1))
# Out:
# 0.062198434089056565

# %%
#test input
test=0.038
val=test/0.038
val_out=lr.predict(np.array([[val]]))
print("Probability that the account is fake: ",val_out[0])
# Out:
# Probability that the account is fake:  0.5043020530081372

# %%
#creating a model on entire data
X=df.drop(['fake','profile_pic'],axis=1)
y=df['fake']
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2, random_state = 8)

# %%
#random forest regression
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=5)
regr.fit(X_train,y_train)
regr.score(X_test, y_test)
# Out:
# 0.6805345817574612

# %%
df.head()
# Out:
#    profile_pic  fullname_words  nums_length_fullname  name_username  \
# 0            1               0                   0.0              0
# 1            1               2                   0.0              0
# 2            1               2                   0.0              0
# 3            1               1                   0.0              0
# 4            1               2                   0.0              0
#
#    description_length  external_URL  private  no_of_posts  no_of_followers  \
# 0                  53             0        0           32             1000
# 1                  44             0        0          286             2740
# 2                   0             0        1           13              159
# 3                  82             0        0          679              414
# 4                   0             0        1            6              151
#
#    no_of_following  fake
# 0              955     0
# 1              533     0
# 2               98     0
# 3              651     0
# 4              126     0

# %%
#let us work on a sample data
val=regr.predict([[0,0.0,0,0,0,1,0,0,11]])
print("The probability that the account is fake is(in %):")
print(val[0]*100)
# Out:
# The probability that the account is fake is(in %):
# 96.29742392083975
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
df['fake'] = [1 if each > 0.75 else 0 for each in df['fake']]
df.head()
# Out:
#    profile_pic  fullname_words  nums_length_fullname  name_username  \
# 0            1               0                   0.0              0
# 1            1               2                   0.0              0
# 2            1               2                   0.0              0
# 3            1               1                   0.0              0
# 4            1               2                   0.0              0
#
#    description_length  external_URL  private  no_of_posts  no_of_followers  \
# 0                  53             0        0           32             1000
# 1                  44             0        0          286             2740
# 2                   0             0        1           13              159
# 3                  82             0        0          679              414
# 4                   0             0        1            6              151
#
#    no_of_following  fake
# 0              955     0
# 1              533     0
# 2               98     0
# 3              651     0
# 4              126     0

# %%
model_rf = RandomForestRegressor(random_state=1)
model_rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
y_pred_rf=model_rf.predict(X_test)
y_pred_rf = [1 if each > 0.75 else 0 for each in y_pred_rf]

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score
from sklearn.metrics import classification_report

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred_rf)
plt.title('Random Forest')
plt.show()
print(f" Accuracy is {accuracy_score(y_test,y_pred_rf)}")
print(classification_report(y_test,y_pred_rf))
# Out:
#  Accuracy is 0.896551724137931
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91        63
#            1       0.98      0.79      0.88        53
#
#     accuracy                           0.90       116
#    macro avg       0.91      0.89      0.89       116
# weighted avg       0.91      0.90      0.89       116
